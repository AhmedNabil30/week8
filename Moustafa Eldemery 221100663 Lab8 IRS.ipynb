# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-c5d0ab7fa392> in <cell line: 72>()
#      87
#      88     # Display metrics
# ---> 89     metrics.display_metrics()
#
# <ipython-input-17-c5d0ab7fa392> in display_metrics(self)
#      54         Display sparsity, time complexity, and space complexity for UBCF and IBCF.
#      55         """
# ---> 56         sparsity = self.calculate_sparsity()
#      57         print(f"Sparsity of the user-item matrix: {sparsity:.2f}")
#      58
#
# <ipython-input-17-c5d0ab7fa392> in calculate_sparsity(self)
#      13         """
#      14         total_elements = self.user_item_matrix.size
# ---> 15         non_zero_elements = np.corunt_nonzero(self.user_item_matrix)
#      16         sparsity = 1 - (non_zero_elements / total_elements)
#      17         return sparsity
#
# ...
